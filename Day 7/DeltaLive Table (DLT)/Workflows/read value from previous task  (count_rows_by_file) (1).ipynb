# %%
# We assume Task 1 in the Job is named "count_rows"

row_count = dbutils.jobs.taskValues.get(
    taskKey="count_rows",      # MUST match Task 1 name in the Job
    key="row_count"
)

file_name = dbutils.jobs.taskValues.get(
    taskKey="count_rows",
    key="file_name"
)

print("📊 Summary from previous task")
print(f"  File name : {file_name}")
print(f"  Row count : {row_count}")
