# %% [markdown]
# ## How to See OPTIMIZE Doing Real Work
# ### Step 1: Write many files artificially

# %%
for i in range(20):
    df = spark.createDataFrame([(i, f"name{i}", 10000+i)], ("id", "name", "salary"))
    df.write.format("delta").mode("append").save("/Volumes/workspace/default/tmp/employees_delta_big")

# %% [markdown]
# This writes **20 separate small files**

# %% [markdown]
# ### Step 2: Run OPTIMIZE

# %%
# %sql
OPTIMIZE delta.`/Volumes/workspace/default/tmp/employees_delta_big`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/tmp/employees_delta_big</td><td>List(1, 20, List(1290, 1290, 1290.0, 1, 1290), List(1023, 1029, 1026.4, 20, 20528), 0, null, null, 0, 1, 20, 0, true, 0, 0, 1763563942711, 1763563945767, 8, 1, null, List(0, 0), null, 3, 3, 450, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ### Visual Explanation
# **Before OPTIMIZE**

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/workspace/default/tmp/employees_delta_big`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>20</td><td>2025-11-19T14:52:26.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> false, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>19</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 20, numRemovedBytes -> 20528, p25FileSize -> 1290, numDeletionVectorsRemoved -> 0, minFileSize -> 1290, numAddedFiles -> 1, maxFileSize -> 1290, p75FileSize -> 1290, p50FileSize -> 1290, numAddedBytes -> 1290)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>19</td><td>2025-11-19T14:51:37.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>18</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>18</td><td>2025-11-19T14:51:36.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>17</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>17</td><td>2025-11-19T14:51:35.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>16</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>16</td><td>2025-11-19T14:51:34.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>15</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>15</td><td>2025-11-19T14:51:33.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>14</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>14</td><td>2025-11-19T14:51:32.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(809526054020352)</td><td>1119-144400-4j5d6qgh-v2n</td><td>13</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1029)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>13</td><td>2025-11-19T14:51:31.000Z</td><td>76766366570240</td><td>geethasamynathan2011@gmail.com</td>< ...

# %%
df_v0 = spark.read.format("delta").option("versionAsOf", 0).load("/Volumes/workspace/default/tmp/employees_delta_big")
display(df_v0)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>0</td><td>name0</td><td>10000</td></tr></tbody></table></div>
